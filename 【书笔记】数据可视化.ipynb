# %%
import matplotlib.pyplot as plt #导入pyplot，用于图形显示
from pandas import DataFrame
gdp=[41.3,48.9,54.0,59.5,64.4,68.9,74.4]
data=DataFrame({'GDP:Trillion':gdp},index=['2010','2011','2012','2013','2014','2015','2016'])
data.plot(kind='bar')
plt.show()

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

GDPdata=[41.3,48.9,54.0,59.5,64.4,68.9,74.4]
plt.plot(GDPdata,color="red",linewidth=2,linestyle='dashed',marker='D',label='GDP')
plt.title('2010~2016 GDP:Trillion')
plt.xlim(0,6)
plt.ylim(35,75)
plt.xticks(range(0,7),('2010','2011','2012','2013','2014','2015','2016'))#将X轴刻度映射为字符串
plt.legend(loc='upper right') #在右上角显示图例说明
plt.grid()

# %% [markdown]
# 多个子图绘制

# %%
# %matplotlib inline
from pandas import Series 
data=Series([41.3,48.9,54,59.5,64.4,68.9,74.4], 
            index=['2010','2011','2012','2013','2014','2015','2016']) 
fig=plt.figure(figsize=(6,6)) #figsize定义图形大小 
ax1=fig.add_subplot(2,1,1)   #创建子图1
ax1.plot(data)      #用AxesSubplot绘制折线图 
ax2=fig.add_subplot(2,2,3)   #创建子图2
data.plot(kind='bar',use_index=True,fontsize='small',ax=ax2)#用pandas绘柱状图
ax3=fig.add_subplot(2,2,4)   #创建子图3 
data.plot(kind='box',fontsize='small',xticks=[],ax=ax3) #用pandas绘柱状图

# %%
fig.savefig('2010-2012GDP.jpg',dpi=400,bbox_inches='tight')

# %%
data.plot(title='2010~2016 GDP',LineWidth=2, marker='o',
          linestyle='dashed',color='r',grid=True,alpha=0.9) 
plt.annotate('turning point',xy=(1,48.5),xytext=(0.5,42),
             arrowprops=dict(arrowstyle='->')) 
plt.text(1.8,70,'GDP keeps booming!',fontsize='larger')
plt.xlabel('Year',fontsize=12) 
plt.ylabel('GDP：Trillion',fontsize=12)

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
from pandas import DataFrame
from pandas import Series 
income=[1.47,1.62,1.78,1.94,2.38,2.60]

data=DataFrame({'Income':income}, 
            index=['2012','2013','2014','2015','2016','2017']) 
data.plot (title='2012-2017 Income chart',Linewidth=2,linestyle='dashed',marker='D',color='black',grid=True,alpha=0.9)
plt.ylim(0,3)
plt.annotate('largest!',xy=(5,2.60),xytext=(3,2.60),arrowprops=dict(arrowstyle='->',color='r'),color='r')

plt.xlabel('Year',fontsize=12)
plt.ylabel('Income(RMB Ten Thousand)',fontsize=12)
# Out:
# Text(0, 0.5, 'Income(RMB Ten Thousand)')

# %%
data=DataFrame({'income':income}, 
            index=['2012','2013','2014','2015','2016','2017']) 
fig=plt.figure(figsize=(6,6)) #figsize定义图形大小 
ax1=fig.add_subplot(2,2,1)   #创建子图1
ax1.plot(data)      #用AxesSubplot绘制折线图 
plt.title('line chart')
plt.xlabel('Year',fontsize=12)
plt.ylabel('Income',fontsize=12)
ax2=fig.add_subplot(2,2,2)   #创建子图3 
data.plot(kind='box',fontsize='small',xticks=[],ax=ax2) #用pandas绘柱状图
plt.title('box-whisker plot')
plt.xlabel('2012-2017',fontsize=12)
plt.ylabel('Income',fontsize=12)
 
ax3=fig.add_subplot(2,1,2)   #创建子图2
data.plot(kind='bar',use_index=True,fontsize='small',ax=ax3)#用pandas绘柱状图
plt.title('bar chart')
plt.xlabel('Year',fontsize=12)
plt.ylabel('Income',fontsize=12)
plt.legend(loc="upper left")
plt.subplots_adjust(left=0.125 ,right=1,bottom=0.1,top=1,wspace=0.5,hspace=0.5)

# %%
import numpy as np
x=np.linspace(0,6.28,50)#start,end,num-points
y=np.sin(x)#计算y=sin(x)数组
plt.plot(x,y,color='r')#用红色绘图y=sin(x)
plt.plot(x,np.exp(-x),c='b')#用蓝色绘图y=exp(-x)

# %%
# %matplotlib inline
import pandas as pd
stdata=pd.read_csv('student.csv')
stdata.plot(kind='scatter',x='Height',y='Weight',title='Students Body Shape',marker='*',grid=True,xlim=[150,200],ylim=[80,130],label='(Height,Weight)')

# %%
data1=stdata[stdata['Gender']==0]
data2=stdata[stdata['Gender']==1]
plt.figure()
plt.scatter(data1['Height'],data1['Weight'],c='r',marker='s',label='Male')
plt.scatter(data2['Height'],data2['Weight'],c='b',marker='^',label='Female')
plt.xlim(150,200)
plt.ylim(80,130)
plt.title('Students Body Shape')
plt.xlabel('Weight')
plt.ylabel('Height')
plt.grid()
plt.legend(loc='upper right')

# %%
data=stdata[['Height','Weight','Age','Score']]
pd.plotting.scatter_matrix(data,diagonal='kde',color='k')
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x191BA2F0>,
# ...
#       dtype=object)

# %%
data=pd.read_csv('population.csv',index_col='Years')
data1=data[['Boys','Girls']]
mean=np.mean(data1,axis=0)  #计算均值
std=np.std(data1,axis=0)   #计算标准差
fig=plt.figure(figsize=(6,2)) #设置图片大小
plt.subplots_adjust(wspace=0.6) #设置两个图之间的纵向间隔
#绘制均值的垂直和水平柱状图，标准差使用误差线来表示
ax1=fig.add_subplot(1,2,1)
mean.plot(kind='bar',yerr=std,color='cadetblue',title='Average of Births',rot=2)
ax2=fig.add_subplot(1,2,2)
mean.plot(kind='barh',xerr=std,color='cadetblue',title='Average of Births')
#绘制复式柱状图和堆叠柱状图
data1.plot(kind='bar',title='Births of Boys&Girls')
data1.plot(kind='bar',stacked=True,title='Births of Boys&Girls')

# %%
data=pd.read_csv('GDP.csv',index_col='Year')
data.plot(title='GDP&Income',LineWidth=2,marker='o',linestyle='dashed',grid=True,use_index=True)
data.plot(logy=True,LineWidth=2,marker='o',linestyle='dashed',color='G')
# Out:
# d:\anaconda\lib\site-packages\pandas\plotting\_matplotlib\style.py:60: MatplotlibDeprecationWarning: Support for uppercase single-letter colors is deprecated since Matplotlib 3.1 and will be removed in 3.3; please use lowercase instead.
#   [conv.to_rgba(c) for c in colors]

# %%
stdata=pd.read_csv('student.csv')
stdata['Height'].plot(kind='hist',bins=6,normed=True,title='Students Height Dstribution',x='Height')
stdata['Height'].plot(kind='kde',title='Students Height Dstribution',xlim=[155,185],style='k--')
# Out:
# d:\anaconda\lib\site-packages\pandas\plotting\_matplotlib\hist.py:62: MatplotlibDeprecationWarning:
# The 'normed' kwarg was deprecated in Matplotlib 2.1 and will be removed in 3.1. Use 'density' instead.
#   n, bins, patches = ax.hist(y, bins=bins, bottom=bottom, **kwds)

# %%
data=pd.read_csv('advertising.csv')
piedata=data[['TV','Weibo','WeChat']]
datasum=piedata.sum()
datasum.plot(kind='pie',figsize=(6,6),title='Advertising Expenditure',fontsize=14,explode=[0,0.2,0],shadow=True,startangle=180,autopct='%1.1f%%')
data
# Out:
#    Unnamed: 0     TV  Weibo  WeChat  Sales
# 0           1  230.1   37.8    69.2   22.1
# 1           2   44.5   39.3    45.1   10.4
# 2           3   17.2   45.9    69.3    9.3

# %%
advdata=data[['TV','Weibo','WeChat']]
advdata.plot(kind='box',figsize=(6,6),title='Advertising Expenditure')

# %%
stdata = pd.read_csv('student.csv')
stdata1 = stdata[['Gender','Score']] 
stdata1.plot(kind='box',figsize=(6,6))
stdata1.boxplot(by='Gender',figsize=(6,6))

# %%
data=pd.read_csv('high-speed rail.csv',index_col='Country')
data['Operation'].plot(kind='bar')
plt.annotate('longest',xy=(0,8000),xytext=(0.5,8000),color='red',arrowprops=dict(arrowstyle='->',color='r'))
plt.title('Operation Mileage')
plt.ylabel('Mileage(km)')
data
# Out:
#          Operation  Under-construction  Planning
# Country
# China         8000                7000      8800
# Italy         3200                8000      9100
# Spanish       3000                9000      9400
# Germany       1500               10000      9700
# France        2000               11000     10000
# Japan         1000               12000     10300

# %%
print("{}".format(data['Planning']))
# Out:
# Country
# China       8800
# Italy       9100
# Spanish     9400
# Germany     9700
# France     10000
# Japan      10300
# Name: Planning, dtype: int64

# %%
data=data[['Operation','Under-construction','Planning']]
pd.plotting.scatter_matrix(data,diagonal='kde',color='k')
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x196AC430>,
# ...
#       dtype=object)

# %%
data1=data.T
data.plot(kind='barh',xlim=(0,16000))
plt.legend(loc='lower right')
data.plot(kind='barh',stacked=True,figsize=(8,3),xlim=(0,50000))
plt.legend(loc='upper right')

# %%
import numpy as np
import matplotlib.pyplot as plt
fraces = data['Operation']
labels='China','Italy','Spanish','Germany','France','Japan'
plt.pie(x=fraces,labels=labels,explode=[0.2,0,0,0,0,0],shadow=True,startangle=180,autopct='%1.1f%%')
plt.show()

# %%
data['Operation'].plot(kind='hist',bins=6,normed=True,title='Operation Dstribution',x='Height')
data['Operation'].plot(kind='kde',title='Operation Dstribution',xlim=[0,10000],style='k--')
# Out:
# d:\anaconda\lib\site-packages\pandas\plotting\_matplotlib\hist.py:62: MatplotlibDeprecationWarning:
# The 'normed' kwarg was deprecated in Matplotlib 2.1 and will be removed in 3.1. Use 'density' instead.
#   n, bins, patches = ax.hist(y, bins=bins, bottom=bottom, **kwds)

# %%
data.plot(kind='scatter',x='Operation',y='Under-construction',marker='*',grid=True,ylim=[0,15000],label='(Operation,Under-construction)',title='Under-construction)')

# %%
data1=data[['Operation','Under-construction','Planning']]
pd.plotting.scatter_matrix(data1,diagonal='hist',color='k')
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x198EAB90>,
# ...
#       dtype=object)

# %%
data1=data[['Operation','Under-construction','Planning']]
mean=np.mean(data1,axis=0)  #计算均值
std=np.std(data1,axis=0)   #计算标准差
fig=plt.figure(figsize=(15,5)) #设置图片大小
plt.subplots_adjust(wspace=0.6) #设置两个图之间的纵向间隔
#绘制均值的垂直和水平柱状图，标准差使用误差线来表示
ax1=fig.add_subplot(1,2,1)
mean.plot(kind='bar',yerr=std,color='cadetblue',title='Average of Births',rot=2)

# %%
data1 = data[['Planning','Operation']] 
data1.plot(kind='box',figsize=(6,6))
data1.boxplot(by='Country',figsize=(16,16))
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x1AD14670>,
# ...
#       dtype=object)
